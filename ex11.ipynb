# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
da ={
    "hour":[1,5,3,6,2],
    "mark":[98,54,78,54,75]
}

# %%
df=pd.DataFrame(da)

# %%
sns.regplot(x="hour",y="mark",data=df)
# Out:
# <Axes: xlabel='hour', ylabel='mark'>

# %%
data =
