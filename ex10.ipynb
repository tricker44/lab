# %%
import numpy as np

# %%
a=np.array([1,2,3,4,9,7])
b=np.array([6,5,5,7,2,5])

# %%
ae=np.corrcoef(a,b)[0,1]

# %%
print(ae)
# Out:
# -0.6992378719789554

# %%
#2 using pearson coefficien
from scipy.stats import pearsonr

# %%
a1,_=pearsonr(a,b)
print(a1)
# Out:
# -0.6992378719789555
