# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
x =pd.Series([1,2,3,4,5,6])

# %%
y=pd.Series([1,2,9,4,5,6])
print(y.corr(x))
# Out:
# 0.5380528418150006

# %%
plt.scatter(x,y)
plt.plot(np.unique(x),np.poly1d(np.polyfit(x,y,1)) (np.unique(x)))
