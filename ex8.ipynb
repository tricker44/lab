# %%
import numpy as np
import seaborn as sns
import scipy.stats as sp

# %%
data =np.arange(1,10,0.01)
pdf=sp.norm.pdf(data,loc=5.3,scale=1)

# %%
sns.set_style('whitegrid')
sns.lineplot(x=data,y=pdf,color='red')
# Out:
# <Axes: >
