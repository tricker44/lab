# %%
list=[1,89,6,5,4,7]

# %%
from statistics import Fraction as fr

# %%
list1=[fr(19,9),fr(92,9)]

# %%
import statistics

# %%
print(statistics.variance(list))
# Out:
# 1191.4666666666667

# %%
print(statistics.variance(list1))
# Out:
# 5329/162

# %%
fro
