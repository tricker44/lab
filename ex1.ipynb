# %%
import numpy as np

# %%
arr =np.array([[19,23,89],[19,80,80],[1,8,3]])

# %%
print(arr.dtype)
# Out:
# int64

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr.shape)
# Out:
# (3, 3)

# %%
print(arr.ndim)
# Out:
# 2

# %%
# Array Slicing :

# %%
arr[1:]
# Out:
# array([[19, 80, 80],
#        [ 1,  8,  3]])

# %%
# Slicing for particular row or number

# %%
arr[1,...]
# Out:
# array([19, 80, 80])

# %%
arr[...,1]
# Out:
# array([23, 80,  8])
